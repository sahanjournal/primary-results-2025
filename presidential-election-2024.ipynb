# %%
import pandas as pd
import urllib.request
import requests
import re

# %%
# update url from state election results website

url = "https://electionresultsfiles.sos.mn.gov/20240305/PNPStatewide.txt"

# %%
# read in data in .txt format

response = requests.get(url)
data = response.text
data = data.replace('\r', '')
data = data.split('\n')

data
# Out:
# ['MN;;;0100;U.S. Presidential Nominee;;0303;Ron DeSantis;;;R;4100;4100;4086;1.21;337731',
#  'MN;;;0100;U.S. Presidential Nominee;;0304;Nikki Haley;;;R;4100;4100;97195;28.78;337731',
#  'MN;;;0100;U.S. Presidential Nominee;;0302;Vivek Ramaswamy;;;R;4100;4100;1471;0.44;337731',
#  'MN;;;0100;U.S. Presidential Nominee;;0301;Donald J. Trump;;;R;4100;4100;232819;68.94;337731',
#  'MN;;;0100;U.S. Presidential Nominee;;0305;Chris Christie;;;R;4100;4100;1436;0.43;337731',
#  'MN;;;0100;U.S. Presidential Nominee;;0306;Write-In;;;R;4100;4100;724;0.21;337731',
#  'MN;;;0100;U.S. Presidential Nominee;;0404;Uncommitted;;;DFL;4100;4100;45910;18.79;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0411;Write-In;;;DFL;4100;4100;1996;0.82;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0402;Joseph R Biden Jr;;;DFL;4100;4100;171255;70.10;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0403;Eban Cambridge;;;DFL;4100;4100;239;0.10;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0408;Gabriel Cornejo;;;DFL;4100;4100;330;0.14;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0407;Frankie Lozada;;;DFL;4100;4100;296;0.12;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0401;Jason Palmer;;;DFL;4100;4100;771;0.32;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0410;Armando "Mando" Perez-Serrato;;;DFL;4100;4100;372;0.15;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0406;Dean Phillips;;;DFL;4100;4100;18964;7.76;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0409;Cenk Uygur;;;DFL;4100;4100;695;0.28;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0405;Marianne Williamson;;;DFL;4100;4100;3462;1.42;244290',
#  'MN;;;0100;U.S. Presidential Nominee;;0604;Edward Forchion;;;LMN;4100;4100;171;6.45;2650',
#  'MN;;;0100;U.S. Presidential Nominee;;0602;Krystal Gabel;;;LMN;4100;4100;762;28.75;2650',
#  'MN;;;0100;U.S. Presidential Nominee;;0603;Dennis Schuller;;;LMN;4100;4100;461;17.40;2650',
#  'MN;;;0100;U.S. Presidential Nominee;;0601;Vermin Supreme;;;LMN;4100;4100;396;14.94;2650',
#  'MN;;;0100;U.S. Presidential Nominee;;0606;Write-In;;;LMN;4100;4100;490;18.49;2650',
#  'MN;;;0100;U.S. Presidential Nominee;;0605;Rudy Reyes;;;LMN;4100;4100;370;13.96;2650',
#  '']

# %%
# save as .txt format
with open('results.txt', 'w') as f:
    for line in data:
        f.write(line)
        f.write('\n')

# %%
# open in pandas as csv format

df = pd.read_csv("results.txt",delimiter = ';',header=None,)
df.head()
# Out:
#    0   1   2    3                          4   5    6                7   8   \
# 0  MN NaN NaN  100  U.S. Presidential Nominee NaN  303     Ron DeSantis NaN
# 1  MN NaN NaN  100  U.S. Presidential Nominee NaN  304      Nikki Haley NaN
# 2  MN NaN NaN  100  U.S. Presidential Nominee NaN  302  Vivek Ramaswamy NaN
# 3  MN NaN NaN  100  U.S. Presidential Nominee NaN  301  Donald J. Trump NaN
# 4  MN NaN NaN  100  U.S. Presidential Nominee NaN  305   Chris Christie NaN
#
#    9  10    11    12      13     14      15
# 0 NaN  R  4100  4100    4086   1.21  337731
# 1 NaN  R  4100  4100   97195  28.78  337731
# 2 NaN  R  4100  4100    1471   0.44  337731
# 3 NaN  R  4100  4100  232819  68.94  337731
# 4 NaN  R  4100  4100    1436   0.43  337731

# %%
# add column names

df.columns = [
    'State',
	'County ID (if applicable)',
	'Precinct name (if applicable)',
	'Office ID',
	'Office Name', 
	'District*',
	'Candidate Order Code',
	'Candidate Name (First/Last/Suffix all in one field)',
	'Suffix (not used)',
	'Incumbent Code (not used)',
	'Party Abbreviation',
	'Number of Precincts reporting',
	'Total number of precincts voting for the office',
	'Votes for Candidate',
	'Percentage of Votes for Candidate out of Total Votes for Office',
	'Total number of votes for Office in area'
]

# %%
# MAKE SOME CHANGES TO THE COLUMN NAMES

df['Candidate Name (First/Last/Suffix all in one field)'] = df['Candidate Name (First/Last/Suffix all in one field)'].str.replace("Write-In","Write-in")


df.rename(columns={"Candidate Name (First/Last/Suffix all in one field)": "Candidate", "Votes for Candidate": "Votes", "Percentage of Votes for Candidate out of Total Votes for Office": "Percentage"}, inplace=True)

# %%
df.head(2)
# Out:
#   State  County ID (if applicable)  Precinct name (if applicable)  Office ID  \
# 0    MN                        NaN                            NaN        100
# 1    MN                        NaN                            NaN        100
#
#                  Office Name  District*  Candidate Order Code     Candidate  \
# 0  U.S. Presidential Nominee        NaN                   303  Ron DeSantis
# 1  U.S. Presidential Nominee        NaN                   304   Nikki Haley
#
#    Suffix (not used)  Incumbent Code (not used) Party Abbreviation  \
# 0                NaN                        NaN                  R
# 1                NaN                        NaN                  R
#
#    Number of Precincts reporting  \
# 0                           4100
# 1                           4100
#
#    Total number of precincts voting for the office  Votes  Percentage  \
# 0                                             4100   4086        1.21
# 1                                             4100  97195       28.78
#
#    Total number of votes for Office in area
# 0                                    337731
# 1                                    337731

# %%
df.to_csv("data/results.csv",index=False)

# %% [markdown]
# ### Republican Primary Race Data

# %%
# select a subset of data for St Paul city council race
GOP = df[df['Party Abbreviation'].str.contains('R')]
GOP
# Out:
#   State  County ID (if applicable)  Precinct name (if applicable)  Office ID  \
# 0    MN                        NaN                            NaN        100
# 1    MN                        NaN                            NaN        100
# 2    MN                        NaN                            NaN        100
# 3    MN                        NaN                            NaN        100
# 4    MN                        NaN                            NaN        100
# 5    MN                        NaN                            NaN        100
#
#                  Office Name  District*  Candidate Order Code  \
# 0  U.S. Presidential Nominee        NaN                   303
# 1  U.S. Presidential Nominee        NaN                   304
# 2  U.S. Presidential Nominee        NaN                   302
# 3  U.S. Presidential Nominee        NaN                   301
# 4  U.S. Presidential Nominee        NaN                   305
# 5  U.S. Presidential Nominee        NaN                   306
#
#          Candidate  Suffix (not used)  Incumbent Code (not used)  \
# 0     Ron DeSantis                NaN                        NaN
# 1      Nikki Haley                NaN                        NaN
# 2  Vivek Ramaswamy                NaN                        NaN
# 3  Donald J. Trump                NaN                        NaN
# 4   Chris Christie                NaN                        NaN
# 5         Write-in                NaN                        NaN
#
#   Party Abbreviation  Number of Precincts reporting  \
# 0                  R                           4100
# 1                  R                           4100
# 2                  R                           4100
# 3                  R                           4100
# 4                  R                           4100
# 5                  R                           4100
#
#    Total number of precincts voting for the office   Votes  Percentage  \
# 0                                             4100    4086        1.21
# 1                                             4100   97195       28.78
# 2                                             4100    1471        0.44
# 3                                             4100  232819       68.94
# 4                                             4100    1436        0.43
# 5                                             4100     724        0.21
#
#    Total number of votes for Office in area
# 0                                    337731
# 1                                    337731
# 2                                    337731
# 3                                    337731
# 4                                    337731
# 5                                    337731

# %%
# Select all columns needed for graphic

GOP = GOP[['Candidate','Votes','Percentage']]

# %%
GOP.head()
# Out:
#          Candidate   Votes  Percentage
# 0     Ron DeSantis    4086        1.21
# 1      Nikki Haley   97195       28.78
# 2  Vivek Ramaswamy    1471        0.44
# 3  Donald J. Trump  232819       68.94
# 4   Chris Christie    1436        0.43

# %%
GOP.to_csv("data/GOP.csv",index=False)

# %% [markdown]
# ## DFL data

# %%
# select a subset of data for DFL

DFL = df[df['Party Abbreviation'].str.contains('DFL')]
DFL
# Out:
#    State  County ID (if applicable)  Precinct name (if applicable)  Office ID  \
# 6     MN                        NaN                            NaN        100
# 7     MN                        NaN                            NaN        100
# 8     MN                        NaN                            NaN        100
# 9     MN                        NaN                            NaN        100
# 10    MN                        NaN                            NaN        100
# 11    MN                        NaN                            NaN        100
# 12    MN                        NaN                            NaN        100
# 13    MN                        NaN                            NaN        100
# 14    MN                        NaN                            NaN        100
# 15    MN                        NaN                            NaN        100
# 16    MN                        NaN                            NaN        100
#
#                   Office Name  District*  Candidate Order Code  \
# 6   U.S. Presidential Nominee        NaN                   404
# 7   U.S. Presidential Nominee        NaN                   411
# 8   U.S. Presidential Nominee        NaN                   402
# 9   U.S. Presidential Nominee        NaN                   403
# 10  U.S. Presidential Nominee        NaN                   408
# 11  U.S. Presidential Nominee        NaN                   407
# 12  U.S. Presidential Nominee        NaN                   401
# 13  U.S. Presidential Nominee        NaN                   410
# 14  U.S. Presidential Nominee        NaN                   406
# 15  U.S. Presidential Nominee        NaN                   409
# 16  U.S. Presidential Nominee        NaN                   405
#
#                         Candidate  Suffix (not used)  \
# 6                     Uncommitted                NaN
# 7                        Write-in                NaN
# 8               Joseph R Biden Jr                NaN
# 9                  Eban Cambridge                NaN
# 10                Gabriel Cornejo                NaN
# 11                 Frankie Lozada                NaN
# 12                   Jason Palmer                NaN
# 13  Armando "Mando" Perez-Serrato                NaN
# 14                  Dean Phillips                NaN
# 15                     Cenk Uygur                NaN
# 16            Marianne Williamson                NaN
#
#     Incumbent Code (not used) Party Abbreviation  \
# 6                         NaN                DFL
# 7                         NaN                DFL
# 8                         NaN                DFL
# 9                         NaN                DFL
# 10                        NaN                DFL
# 11                        NaN                DFL
# 12                        NaN                DFL
# 13                        NaN                DFL
# 14                        NaN                DFL
# 15                        NaN                DFL
# 16                        NaN                DFL
#
#     Number of Precincts reporting  \
# 6                            4100
# 7                            4100
# 8                            4100
# 9                            4100
# 10                           4100
# 11                           4100
# 12                           4100
# 13                           4100
# 14                           4100
# 15                           4100
# 16                           4100
#
#     Total number of precincts voting for the office   Votes  Percentage  \
# 6                                              4100   45910       18.79
# 7                                              4100    1996        0.82
# 8                                              4100  171255       70.10
# 9                                              4100     239        0.10
# 10                                             4100     330        0.14
# 11                                             4100     296        0.12
# 12                                             4100     771        0.32
# 13                                             4100     372        0.15
# 14                                             4100   18964        7.76
# 15                                             4100     695        0.28
# 16                                             4100    3462        1.42
#
#     Total number of votes for Office in area
# 6                                     244290
# 7                                     244290
# 8                                     244290
# 9                                     244290
# 10                                    244290
# 11                                    244290
# 12                                    244290
# 13                                    244290
# 14                                    244290
# 15                                    244290
# 16                                    244290

# %%
DFL = DFL[['Candidate','Votes','Percentage']]

DFL.head()
# Out:
#             Candidate   Votes  Percentage
# 6         Uncommitted   45910       18.79
# 7            Write-in    1996        0.82
# 8   Joseph R Biden Jr  171255       70.10
# 9      Eban Cambridge     239        0.10
# 10    Gabriel Cornejo     330        0.14

# %%
DFL.to_csv("data/DFL.csv",index=False)

# %% [markdown]
# ### LMN Results

# %%
# select a subset of data for LMN

LMN = df[df['Party Abbreviation'].str.contains('LMN')]
LMN
# Out:
#    State  County ID (if applicable)  Precinct name (if applicable)  Office ID  \
# 17    MN                        NaN                            NaN        100
# 18    MN                        NaN                            NaN        100
# 19    MN                        NaN                            NaN        100
# 20    MN                        NaN                            NaN        100
# 21    MN                        NaN                            NaN        100
# 22    MN                        NaN                            NaN        100
#
#                   Office Name  District*  Candidate Order Code  \
# 17  U.S. Presidential Nominee        NaN                   604
# 18  U.S. Presidential Nominee        NaN                   602
# 19  U.S. Presidential Nominee        NaN                   603
# 20  U.S. Presidential Nominee        NaN                   601
# 21  U.S. Presidential Nominee        NaN                   606
# 22  U.S. Presidential Nominee        NaN                   605
#
#           Candidate  Suffix (not used)  Incumbent Code (not used)  \
# 17  Edward Forchion                NaN                        NaN
# 18    Krystal Gabel                NaN                        NaN
# 19  Dennis Schuller                NaN                        NaN
# 20   Vermin Supreme                NaN                        NaN
# 21         Write-in                NaN                        NaN
# 22       Rudy Reyes                NaN                        NaN
#
#    Party Abbreviation  Number of Precincts reporting  \
# 17                LMN                           4100
# 18                LMN                           4100
# 19                LMN                           4100
# 20                LMN                           4100
# 21                LMN                           4100
# 22                LMN                           4100
#
#     Total number of precincts voting for the office  Votes  Percentage  \
# 17                                             4100    171        6.45
# 18                                             4100    762       28.75
# 19                                             4100    461       17.40
# 20                                             4100    396       14.94
# 21                                             4100    490       18.49
# 22                                             4100    370       13.96
#
#     Total number of votes for Office in area
# 17                                      2650
# 18                                      2650
# 19                                      2650
# 20                                      2650
# 21                                      2650
# 22                                      2650

# %%
LMN = LMN[['Candidate','Votes','Percentage']]

# %%
LMN.to_csv("data/LMN.csv",index=False)

# %% [markdown]
# ### Precincts reported

# %%
progress = df[['Number of Precincts reporting','Total number of precincts voting for the office']].head(1)
progress['pct'] = progress['Number of Precincts reporting'] / progress['Total number of precincts voting for the office']
progress['unreported'] = 1-progress['pct']
progress
# Out:
#    Number of Precincts reporting  \
# 0                           4100
#
#    Total number of precincts voting for the office  pct  unreported
# 0                                             4100  1.0         0.0

# %%
progress.to_json("data/progress.json",index=False)
